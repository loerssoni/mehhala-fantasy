# %%
# %load_ext autoreload
# %autoreload 2
from yfpy.query import YahooFantasySportsQuery
import sys
sys.path.append('../src')

# %%
def get_ts(t):
    return pd.Timestamp(t, unit='s', tz='UTC')\
        .tz_convert('US/Pacific')

def iso_get_ts(t):
    return pd.Timestamp(t).tz_convert('US/Pacific')

def get_gameweek(date):
    import requests
    games = []
    url = f'https://api-web.nhle.com/v1/schedule/{date}'
    r = requests.get(url)
    if r.status_code != 200:
        print(r.text)
    data = r.json()
    for week in data['gameWeek']:
        for game in week['games']:
            games.append({
                'gameId': game['id'],
                'home': game['homeTeam']['abbrev'],
                'away': game['awayTeam']['abbrev'],
                'ts': iso_get_ts(game['startTimeUTC']).date()
            })
    return games, data.get('nextStartDate')

def get_schedule(dates):
    games = []
    next_start = dates[0].strftime('%Y-%m-%d')
    for date in dates:
        if date >= pd.Timestamp(next_start):
            g, next_start = get_gameweek(date.strftime('%Y-%m-%d'))
            games += g
    games = [g for g in games if dates[0].date() <= g['ts'] <= dates[-1].date()]
    return games

# %%
def get_moves(t):
    moves = []
    for p in t.players:
        if p.transaction_data.destination_team_key:
            moves.append({'player': p.player_key, 'to': p.transaction_data.destination_team_key})
        if p.transaction_data.source_team_key:
            moves.append({'player': p.player_key, 'from': p.transaction_data.source_team_key})
    return moves


def argsort(seq):
    return sorted(range(len(seq)), key=seq.__getitem__)

def get_transactions(q):
    transactions = q.get_league_transactions()
    transactions = [transactions[i] for i in argsort([t.timestamp for t in transactions])]
    tr_by_date = {}
    for t in transactions:
        k = (get_ts(t.timestamp) + pd.Timedelta('1d')).date()
        if k not in tr_by_date.keys():
            tr_by_date[k] = []
        tr_by_date[k] += get_moves(t)
    return tr_by_date

# %%
def get_initial_teams(q):
    players = q.get_league_draft_results()
    teams = {}
    for p in players:
        if p.team_key not in teams:
            teams[p.team_key] = []
        teams[p.team_key].append(p.player_key)
    return teams

def get_teams(q):
    s = q.get_league_settings()
    dates = pd.date_range(get_ts(s.draft_time).strftime('%Y-%m-%d'),
              weeks[-1].end, freq='d').date

    from copy import deepcopy

    teams = {}
    transactions = get_transactions(q)
    current_teams = get_initial_teams(q)
    for date in dates:
        trs = transactions.get(date, [])
        for move in trs:
            if 'to' in move:
                current_teams[move['to']].append(move['player'])
            if 'from' in move:
                current_teams[move['from']].remove(move['player'])
        teams[date] = deepcopy(current_teams)

    df = pd.DataFrame(teams).T.melt(var_name='team_id', value_name='player', ignore_index=False)
    df = df.reset_index()
    df = df.join(df.player.explode(), rsuffix='_key', validate='one_to_many')
    df['index'] = pd.to_datetime(df['index'])
    df = df.drop('player', axis=1).set_index('index')
    df.index.name = 'date'
    return df

# %%
import pandas as pd
def get_players(q):
    players = q.get_league_players()
    pdf = pd.DataFrame([{
    'pos':p.display_position.split(','), 
    'name': p.name.full, 
    'player_key':p.player_key, 
    'team': p.editorial_team_abbr,
    'status': p.status 
     } for p in players])
    names_map = pd.read_csv('data/name_mapping.csv', index_col='name_match')
    bios = pd.read_csv('data/bios.csv')
    bios['name'] = bios[['name']].replace(names_map.to_dict())['name']
    pdf = pdf.merge(bios, how='inner', on='name', suffixes=('_yh', ''))
    return pdf

# %%
from get_data import load_history, load_current, combine_history, process_pca, process_y, load_bios, load_team_data
# load_history()
# load_current()
# combine_history()
# load_team_data()
# load_bios()
# process_pca()
# process_y()
# Out:
# Loaded bios, writing to csv.
# Read in game data.
# Processed pca, writing to csv
# Processed y, writing to csv

# %%
game_id = 427
# game_id = 453

league_id = 21834
q = YahooFantasySportsQuery(
    game_id = game_id,
    league_id = league_id,
    game_code = 'nhl',
    auth_dir = '/home/jupyter/creds',
    browser_callback = False,
)

# %%
# weeks = q.get_game_weeks_by_game_id(game_id)
players = get_players(q)
# teams = get_teams(q)
# teams = teams.reset_index().merge(players, on='player_key', how='left')
# Out:
# 2024-09-23 13:26:24.042 - ERROR - query.py - yfpy.query:291 - No data found when attempting extraction from fields: ['league', 'players']

# %%
from process_data import get_player_stats, get_team_stats, get_bios, run_training, INDEX_COLS, PRED_COLS
X_p, y = get_player_stats()
X_b = get_bios(X_p)
X_t = get_team_stats()

# %%
X = X_p.groupby('playerId').shift(1)
X = X.join(X_b)

X_pt = X_t.groupby('team').shift(1).copy()
X_pt['home'] = X_t['home'].copy()

X_pt.index.names = ['opposingTeam','gameId','gameDate']
X = X.join(X_pt, rsuffix='_opp')

X_pt.index.names = ['playerTeam','gameId','gameDate']
X = X.join(X_pt, rsuffix='_team')

X = X.reset_index().set_index(INDEX_COLS)
X = X[~X[[str(i) for i in range(35)]].isna().all(1)]
y = y.loc[X.index]

# %%
pipes = run_training(X, y, True)
# Out:
# fow -- 0.7414251367418632
# fow -- 0.7901185749527758
# goals -- 0.07357906986823237
# goals -- 0.2720227817788389
# assists -- 0.08688721114812958
# assists -- 0.39888354828236905
# shots -- 0.2257047788509583
# shots -- 1.0684372334351537
# hits -- 0.16546566719263378
# hits -- 1.0118081149267546
# blocks -- 0.2236169059349279
# blocks -- 0.7654522918586214
# pim -- 0.02645390322644614
# pim -- 0.7137072948602097
# goalsfor -- 0.03874478359033917
# goalsfor -- 0.6289361285565018
# goalsaga -- 0.025841764003764034
# goalsaga -- 0.6291549350778155
# ppp -- 0.10559534277704385
# ppp -- 0.15195601095192351

# %% [markdown]
# ## DRAFT

# %%
game_id = 427

q = YahooFantasySportsQuery(
    game_id = game_id,
    league_id = league_id,
    game_code = 'nhl',
    auth_dir = '/home/jupyter/creds',
    browser_callback = False,
)

all_matchups = []
for i in range(1, 27):
    all_matchups += q.get_league_matchups_by_week(i)
    
stats_map = {
    1: 'goals',
    2: 'assists',
    4: 'plusmin',
    5: 'pim',
    8: 'ppp',
    14: 'shots',
    16: 'fow',
    31: 'hits',
    32: 'blocks'
}
stats = []
for match in all_matchups:
    for mt in match.teams:
        for s in mt.team_stats.stats:
            stats.append({'id': s.stat_id, 'val': s.value})
stats = pd.DataFrame(stats)
stats['name'] = stats.id.apply(lambda x: stats_map.get(x, None))
s_exp = stats.groupby('name')['val'].mean()

# %%
game_id = 453
q = YahooFantasySportsQuery(
    game_id = game_id,
    league_id = league_id,
    game_code = 'nhl',
    auth_dir = '/home/jupyter/creds',
    browser_callback = False,
)

# %%
def get_week_data(dates, games, X_p, X_t, week):
    dates = pd.to_datetime(X_p.index.get_level_values('gameDate'), format='%Y%m%d')
    
    if week is not None:
        filtered = dates < week.start
    else:
        filtered = [True for i in range(len(dates))]
    
    player_stats = X_p[filtered].reset_index(level='playerTeam').groupby(['playerId']).last()
    
    dates = pd.to_datetime(X_t.index.get_level_values('gameDate'), format='%Y%m%d')
    
    if week is not None:
        filtered = dates < week.start
    else:
        filtered = [True for i in range(len(dates))]  
    
    team_stats = X_t[filtered].groupby('team').last()
    team_stats = team_stats.drop('home', axis=1)
    gs = pd.DataFrame(games)

    home_games = gs.merge(player_stats.reset_index(), left_on='home', right_on='playerTeam')
    home_games = home_games.merge(team_stats.reset_index(), left_on='home', right_on='team', suffixes=('', '_team'))
    home_games = home_games.merge(team_stats.reset_index(), left_on='away', right_on='team', suffixes=('', '_opp'))

    away_games = gs.merge(player_stats.reset_index(), left_on='away', right_on='playerTeam')
    away_games = away_games.merge(team_stats.reset_index(), left_on='away', right_on='team', suffixes=('', '_team'))
    away_games = away_games.merge(team_stats.reset_index(), left_on='home', right_on='team', suffixes=('', '_opp'))

    gs = pd.concat([home_games, away_games]).sort_values('gameId')
    gs['home_team'] = (gs['playerTeam']  == gs['home']).astype(int)
    gs['gameDate'] = pd.to_datetime(gs['ts'])
    gs['opposingTeam'] = gs.apply(lambda row: row['home'] if row['playerTeam'] == row['away'] else row['away'], axis=1)
    gs = gs.set_index(['gameId','gameDate','playerId','playerTeam', 'opposingTeam'])
    bios = get_bios(gs)
    gs = gs.join(bios)
    gs['home'] = 1 - gs['home_team']
    return gs

def get_opponent(m):
    m_t = [t.team_key for t in m.teams]
    if own_team in m_t:
        opponent = [t for t in m_t if t != own_team][0]
    return opponent

from scipy import stats
def get_added_val(x, opp_exp, stat_cols):
    vals = {}
    for col in stat_cols:
        if col == 'plusmin':
            vals[col] = stats.skellam.cdf(0, opp_exp['goalsfor']+x['goalsaga'], opp_exp['goalsaga']+x['goalsfor'])
        else:
            vals[col] = stats.skellam.cdf(0, opp_exp[col], x[col])
    return vals

def get_added_vals(all_preds, opp_exp=None, own_team_length=1):
    if opp_exp is None:
        opp_exp = get_dummy_team(all_preds, own_team_length)
    
    stat_cols = ['goals', 'assists', 'shots', 'hits', 'blocks', 'pim', 'fow', 'plusmin', 'ppp']
    total_vals = all_preds.apply(lambda x: pd.Series(get_added_val(x, opp_exp, stat_cols)), 1).fillna(0)
    return total_vals.sum(1)

# %%
def can_include_player(new_player, position_lookup, selected_players, position_limits, wildcard=None):
    from collections import defaultdict

    # Helper function to check if the current assignment of players to positions is valid
    def is_valid_assignment(assignments):
        counts = defaultdict(int)
        for player, pos in assignments.items():
            counts[pos] += 1
            if counts[pos] > position_limits.get(pos, 0):
                return False
        return True
    
    # Helper function for the backtracking algorithm
    def backtrack(assignments, players):
        if not players:
            return is_valid_assignment(assignments)
        
        current_player = players[0]
        possible_positions = position_lookup.get(current_player, [])
        
        # Include wildcard positions if the current player is the wildcard
        if current_player == wildcard:
            possible_positions = position_limits.keys()
        
        for pos in possible_positions:
            assignments[current_player] = pos
            if is_valid_assignment(assignments):
                if backtrack(assignments, players[1:]):
                    return True
            assignments.pop(current_player, None)
        return False
    
    # List of players to be considered (already selected + new player)
    all_players = selected_players + [new_player]
    
    # Initial assignments
    initial_assignments = {}
    
    # Run the backtracking algorithm
    return backtrack(initial_assignments, all_players)

# %%
games_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 games_df
#
# NameError: name 'games_df' is not defined

# %%
def get_days_games(date, game_df, players, selected_team):
    position_lookup = players.set_index('playerId')['pos'].to_dict()
    position_limits = {
        'D': 4,
        'C': 2,
        'RW': 2,
        'LW': 2,
        'G': 0
    }
    todays_games = game_df]
    
    todays_players = todays_games[todays_games.index.get_level_values('playerId').isin(selected_team)].index.get_level_values('playerId').tolist()

    is_included = todays_games.reset_index(level='playerId')['playerId'].apply(lambda x: can_include_player(x, position_lookup, todays_players, position_limits, wildcard=None)).values
    is_inteam = todays_games.reset_index(level='playerId')['playerId'].isin(selected_team).values
    todays_games = todays_games[is_included|is_inteam]
    return todays_games

def get_week_games(dates, preds, players, selected_team):
    week_games = []
    for date in dates:
        week_games.append(get_days_games(date, preds, players, selected_team))
    week_games = pd.concat(week_games)
    return week_games

# %%
players
# Out:
#       pos               name   player_key team_yh status  playerId position  \
# 0     [G]  Marc-Andre Fleury   453.p.3341     MIN          8470594        G
# 1     [D]         Ryan Suter   453.p.3345     STL          8470600        D
# 2     [D]        Brent Burns   453.p.3358     CAR          8470613        D
# 3    [RW]        Corey Perry   453.p.3365     EDM          8470621        R
# 4    [LW]      Alex Ovechkin   453.p.3637     WSH    DTD   8471214        L
# ..    ...                ...          ...     ...    ...       ...      ...
# 960   [D]        Patrik Koch  453.p.31276     UTA          8484326        D
# 961   [D]        Lane Hutson  453.p.31751     MTL          8483457        D
# 962  [LW]    Cutter Gauthier  453.p.31759     ANA          8483445        L
# 963   [D]   Elias Pettersson  453.p.32762     VAN          8480012        C
# 964  [RW]        Collin Graf  453.p.32811      SJ          8484911        R
#
#     team   birthDate  weight height nationality shootsCatches  primaryNumber  \
# 0    MIN  1984-11-28   180.0  6' 2"         CAN             L           29.0
# 1    DAL  1985-01-21   208.0  6' 2"         USA             L           20.0
# 2    CAR  1985-03-09   230.0  6' 5"         CAN             R           88.0
# 3    EDM  1985-05-16   206.0  6' 3"         CAN             R           10.0
# 4    WSH  1985-09-17   235.0  6' 3"         RUS             R            8.0
# ..   ...         ...     ...    ...         ...           ...            ...
# 960  ARI         NaN     NaN    NaN         NaN           NaN            NaN
# 961  MTL         NaN     NaN    NaN         NaN           NaN            NaN
# 962  ANA         NaN     NaN    NaN         NaN           NaN            NaN
# 963  VAN  1998-11-12   176.0  6' 2"         SWE             L           40.0
# 964  SJS         NaN     NaN    NaN         NaN           NaN            NaN
#
#     primaryPosition
# 0                 G
# 1                 D
# 2                 D
# 3                 R
# 4                 L
# ..              ...
# 960             NaN
# 961             NaN
# 962             NaN
# 963               C
# 964             NaN
#
# [965 rows x 15 columns]

# %%
def get_preds(pipes, gs):
    import numpy as np
    preds = {}
    for c in PRED_COLS:
        preds[c] = pipes[c].predict(gs[pipes[c].feature_names_in_])
        preds[c] = np.clip(preds[c], 0, np.inf)

    preds = pd.DataFrame(preds, index=gs.index)
    return preds

def get_results(dates, preds, players, selected_team):
    player_ids = get_week_games(dates, preds, players.iloc[:0], selected_team)
    player_ids = player_ids.join(players.groupby('playerId')['player_key'].first()).groupby('gameDate')['player_key'].apply(list).to_dict()
    stats_map = {
        1: 'goals',
        2: 'assists',
        4: 'plusmin',
        5: 'pim',
        8: 'ppp',
        14: 'shots',
        16: 'fow',
        31: 'hits',
        32: 'blocks'
    }
    results = []
    for d, ps in player_ids.items():
        for p in ps:
            pstats = q.get_player_stats_by_date(p, d.strftime('%Y-%m-%d')).player_stats.stats
            pstats = {stats_map[s.stat_id]: s.value for s in pstats}
            results.append(pstats)
    return pd.DataFrame(results).sum()

# %%
dates = pd.date_range('2024-09-23', '2025-06-01')
games = get_schedule(dates)

# %%
# dates = pd.date_range('2024-10-01', '2025-06-01')
# games = get_schedule(dates)
# gs = get_week_data(dates, games, X_p, X_t, week=None)

# preds = get_preds(pipes, gs)


opp_exp = pd.DataFrame(s_exp).T
opp_exp['goalsfor'] = opp_exp['plusmin']
opp_exp['goalsaga'] = 0


selected_team = [
    8478550,
    8478542,
    8476455
    
]
taken = [
    8471214,
    8480012,
    8475798,
    8470600         
]

player_info = players.set_index('playerId')[['name', 'pos']]
while len(selected_team) < 14:
    week_ind_preds = get_week_games(dates, preds, players, selected_team)
    week_preds = week_ind_preds.groupby('playerId').sum()

    current_exp = week_preds[~week_preds.index.isin(taken+selected_team)].copy()

    if len(selected_team) == 0:
        current_exp = week_preds.iloc[[0]] * 0
    
    exp = get_added_vals(current_exp, opp_exp.sum())
    selected_team.append(exp.idxmax())
    print('TEAM\n', player_info.loc[selected_team])
# Out:
# TEAM
#                         name      pos
# playerId
# 8478550      Artemi Panarin     [LW]
# 8478542      Evan Rodrigues  [C, LW]
# 8476455   Gabriel Landeskog     [LW]
# 8479318     Auston Matthews      [C]
# TEAM
#                         name      pos
# playerId
# 8478550      Artemi Panarin     [LW]
# 8478542      Evan Rodrigues  [C, LW]
# 8476455   Gabriel Landeskog     [LW]
# 8479318     Auston Matthews      [C]
# 8476468         J.T. Miller  [C, RW]
# TEAM
#                         name      pos
# playerId
# 8478550      Artemi Panarin     [LW]
# 8478542      Evan Rodrigues  [C, LW]
# 8476455   Gabriel Landeskog     [LW]
# 8479318     Auston Matthews      [C]
# 8476468         J.T. Miller  [C, RW]
# 8478493    Joel Eriksson Ek      [C]
# TEAM
#                         name      pos
# playerId
# 8478550      Artemi Panarin     [LW]
# 8478542      Evan Rodrigues  [C, LW]
# 8476455   Gabriel Landeskog     [LW]
# 8479318     Auston Matthews      [C]
# 8476468         J.T. Miller  [C, RW]
# 8478493    Joel Eriksson Ek      [C]
# 8478420      Mikko Rantanen     [RW]
# TEAM
#                         name      pos
# playerId
# 8478550      Artemi Panarin     [LW]
# 8478542      Evan Rodrigues  [C, LW]
# 8476455   Gabriel Landeskog     [LW]
# 8479318     Auston Matthews      [C]
# 8476468         J.T. Miller  [C, RW]
# 8478493    Joel Eriksson Ek      [C]
# 8478420      Mikko Rantanen     [RW]
# 8478427       Sebastian Aho      [C]
# 8478427       Sebastian Aho      [D]
# TEAM
#                         name      pos
# playerId
# 8478550      Artemi Panarin     [LW]
# 8478542      Evan Rodrigues  [C, LW]
# 8476455   Gabriel Landeskog     [LW]
# 8479318     Auston Matthews      [C]
# 8476468         J.T. Miller  [C, RW]
# 8478493    Joel Eriksson Ek      [C]
# 8478420      Mikko Rantanen     [RW]
# 8478427       Sebastian Aho      [C]
# 8478427       Sebastian Aho      [D]
# 8477934      Leon Draisaitl  [C, LW]
# TEAM
#                         name      pos
# playerId
# 8478550      Artemi Panarin     [LW]
# 8478542      Evan Rodrigues  [C, LW]
# 8476455   Gabriel Landeskog     [LW]
# 8479318     Auston Matthews      [C]
# 8476468         J.T. Miller  [C, RW]
# 8478493    Joel Eriksson Ek      [C]
# 8478420      Mikko Rantanen     [RW]
# 8478427       Sebastian Aho      [C]
# 8478427       Sebastian Aho      [D]
# 8477934      Leon Draisaitl  [C, LW]
# 8474578       Erik Karlsson      [D]
# TEAM
#                         name      pos
# playerId
# 8478550      Artemi Panarin     [LW]
# 8478542      Evan Rodrigues  [C, LW]
# 8476455   Gabriel Landeskog     [LW]
# 8479318     Auston Matthews      [C]
# 8476468         J.T. Miller  [C, RW]
# 8478493    Joel Eriksson Ek      [C]
# 8478420      Mikko Rantanen     [RW]
# 8478427       Sebastian Aho      [C]
# 8478427       Sebastian Aho      [D]
# 8477934      Leon Draisaitl  [C, LW]
# 8474578       Erik Karlsson      [D]
# 8474600          Roman Josi      [D]
# TEAM
#                         name      pos
# playerId
# 8478550      Artemi Panarin     [LW]
# 8478542      Evan Rodrigues  [C, LW]
# 8476455   Gabriel Landeskog     [LW]
# 8479318     Auston Matthews      [C]
# 8476468         J.T. Miller  [C, RW]
# 8478493    Joel Eriksson Ek      [C]
# 8478420      Mikko Rantanen     [RW]
# 8478427       Sebastian Aho      [C]
# 8478427       Sebastian Aho      [D]
# 8477934      Leon Draisaitl  [C, LW]
# 8474578       Erik Karlsson      [D]
# 8474600          Roman Josi      [D]
# 8480839       Rasmus Dahlin      [D]
# TEAM
#                         name       pos
# playerId
# 8478550      Artemi Panarin      [LW]
# 8478542      Evan Rodrigues   [C, LW]
# 8476455   Gabriel Landeskog      [LW]
# 8479318     Auston Matthews       [C]
# 8476468         J.T. Miller   [C, RW]
# 8478493    Joel Eriksson Ek       [C]
# 8478420      Mikko Rantanen      [RW]
# 8478427       Sebastian Aho       [C]
# 8478427       Sebastian Aho       [D]
# 8477934      Leon Draisaitl   [C, LW]
# 8474578       Erik Karlsson       [D]
# 8474600          Roman Josi       [D]
# 8480839       Rasmus Dahlin       [D]
# 8479314     Matthew Tkachuk  [LW, RW]
# TEAM
#                         name       pos
# playerId
# 8478550      Artemi Panarin      [LW]
# 8478542      Evan Rodrigues   [C, LW]
# 8476455   Gabriel Landeskog      [LW]
# 8479318     Auston Matthews       [C]
# 8476468         J.T. Miller   [C, RW]
# 8478493    Joel Eriksson Ek       [C]
# 8478420      Mikko Rantanen      [RW]
# 8478427       Sebastian Aho       [C]
# 8478427       Sebastian Aho       [D]
# 8477934      Leon Draisaitl   [C, LW]
# 8474578       Erik Karlsson       [D]
# 8474600          Roman Josi       [D]
# 8480839       Rasmus Dahlin       [D]
# 8479314     Matthew Tkachuk  [LW, RW]
# 8478402      Connor McDavid       [C]

# %%
player_info.name.to_dict()
# Out:
# {8470594: 'Marc-Andre Fleury',
#  8470600: 'Ryan Suter',
#  8470613: 'Brent Burns',
#  8470621: 'Corey Perry',
#  8471214: 'Alex Ovechkin',
#  8471215: 'Evgeni Malkin',
#  8471218: 'Blake Wheeler',
#  8471675: 'Sidney Crosby',
#  8471677: 'Jack Johnson',
#  8471685: 'Anze Kopitar',
#  8471698: 'T.J. Oshie',
#  8471709: 'Marc-Edouard Vlasic',
#  8473446: 'Erik Johnson',
#  8473533: 'Jordan Staal',
#  8473563: 'Nicklas Backstrom',
#  8473449: 'Kyle Okposo',
#  8473453: 'Trevor Lewis',
#  8473512: 'Claude Giroux',
#  8473575: 'Semyon Varlamov',
#  8473422: 'Nick Foligno',
#  8471724: 'Kris Letang',
#  8471734: 'Jonathan Quick',
#  8471817: 'Ryan Reaves',
#  8473504: 'Cal Clutterbuck',
#  8474141: 'Patrick Kane',
#  8474037: 'James van Riemsdyk',
#  8474053: 'Logan Couture',
#  8474151: 'Ryan McDonagh',
#  8474189: 'Lars Eller',
#  8474013: 'Ian Cole',
#  8474157: 'Max Pacioretty',
#  8474150: 'Mikael Backlund',
#  8474102: 'David Perron',
#  8474090: 'Brendan Smith',
#  8473419: 'Brad Marchand',
#  8474034: 'Pat Maroon',
#  8473503: 'James Reimer',
#  8474166: 'Alec Martinez',
#  8474564: 'Steven Stamkos',
#  8474563: 'Drew Doughty',
#  8474567: 'Zach Bogosian',
#  8474565: 'Alex Pietrangelo',
#  8474568: 'Luke Schenn',
#  8474574: 'Tyler Myers',
#  8474578: 'Erik Karlsson',
#  8474586: 'Jordan Eberle',
#  8474590: 'John Carlson',
#  8473994: 'Jamie Benn',
#  8474596: 'Jake Allen',
#  8475166: 'John Tavares',
#  8475167: 'Victor Hedman',
#  8475168: 'Matt Duchene',
#  8475169: 'Evander Kane',
#  8475170: 'Brayden Schenn',
#  8475171: 'Oliver Ekman-Larsson',
#  8475172: 'Nazem Kadri',
#  8475176: 'Ryan Ellis',
#  8475177: 'Calvin de Haan',
#  8475179: 'Dmitry Kulikov',
#  8475181: 'Nick Leddy',
#  8475184: 'Chris Kreider',
#  8475149: 'Marcus Johansson',
#  8475151: 'Kyle Palmieri',
#  8474673: 'TJ Brodie',
#  8474149: 'Evgenii Dadonov',
#  8474145: 'Robert Bortuzzo',
#  8474612: 'Travis Hamonic',
#  8475231: 'Casey Cizikas',
#  8475220: 'Marcus Foligno',
#  8475158: "Ryan O'Reilly",
#  8475193: 'Tomas Tatar',
#  8473507: 'Jeff Petry',
#  8475660: 'Cam Talbot',
#  8475246: 'Kevin Connauton',
#  8475683: 'Sergei Bobrovsky',
#  8475692: 'Mats Zuccarello',
#  8474600: 'Roman Josi',
#  8475690: 'Chris Tanev',
#  8474593: 'Jacob Markstrom',
#  8475233: 'David Savard',
#  8475791: 'Taylor Hall',
#  8475794: 'Tyler Seguin',
#  8475790: 'Erik Gudbranson',
#  8475799: 'Nino Niederreiter',
#  8475784: 'Jeff Skinner',
#  8475798: 'Mikael Granlund',
#  8475789: 'Jack Campbell',
#  8475764: 'Cam Fowler',
#  8475768: 'Jaden Schwartz',
#  8475762: 'Derek Forbort',
#  8475765: 'Vladimir Tarasenko',
#  8475766: 'Austin Watson',
#  8475760: 'Nick Bjugstad',
#  8475797: 'Jarred Tinordi',
#  8475763: 'Kevin Hayes',
#  8475744: 'Evgeny Kuznetsov',
#  8475745: 'Charlie Coyle',
#  8475754: 'Brock Nelson',
#  8475755: 'Alexander Petrovic',
#  8475753: 'Justin Faulk',
#  8475750: 'Jon Merrill',
#  8475726: 'Tyler Toffoli',
#  8475717: 'Calvin Pickard',
#  8475714: 'Calle Jarnkrok',
#  8475718: 'Justin Holl',
#  8475722: 'Jason Zucker',
#  8475462: 'Radko Gudas',
#  8475810: 'Bryan Rust',
#  8475809: 'Scott Wedgewood',
#  8475825: 'Jani Hakanpaa',
#  8475831: 'Philipp Grubauer',
#  8475780: 'Chris Wagner',
#  8475786: 'Zach Hyman',
#  8475906: 'John Klingberg',
#  8475839: 'Louis Domingue',
#  8475852: 'Petr Mrazek',
#  8475842: 'Sam Carrick',
#  8475848: 'Brendan Gallagher',
#  8475855: 'Jesper Fast',
#  8475913: 'Mark Stone',
#  8475883: 'Frederik Andersen',
#  8475958: 'Michael Sgarbossa',
#  8475188: 'Brayden McNabb',
#  8474716: 'Jared Spurgeon',
#  8474641: 'Adam Henrique',
#  8475455: 'Brenden Dillon',
#  8475200: 'Dmitry Orlov',
#  8474870: 'Tyler Johnson',
#  8475279: 'Ben Chiarot',
#  8474679: 'Gustav Nyquist',
#  8475197: 'Tyson Barrie',
#  8474715: 'Cam Atkinson',
#  8475218: 'Mattias Ekholm',
#  8475311: 'Darcy Kuemper',
#  8475235: 'Nicolas Deslauriers',
#  8476454: 'Ryan Nugent-Hopkins',
#  8476455: 'Gabriel Landeskog',
#  8476456: 'Jonathan Huberdeau',
#  8476457: 'Adam Larsson',
#  8476458: 'Ryan Strome',
#  8476459: 'Mika Zibanejad',
#  8476460: 'Mark Scheifele',
#  8476461: 'Sean Couturier',
#  8476462: 'Dougie Hamilton',
#  8476463: 'Jonas Brodin',
#  8476467: 'Jamie Oleksiak',
#  8476468: 'J.T. Miller',
#  8476469: 'Joel Armia',
#  8476473: 'Connor Murphy',
#  8476474: 'Stefan Noesen',
#  8476479: 'Phillip Danault',
#  8476480: 'Vladislav Namestnikov',
#  8476483: 'Rickard Rakell',
#  8475225: 'Craig Smith',
#  8476429: 'Scott Mayfield',
#  8476432: 'Boone Jenner',
#  8476433: 'Magnus Hellberg',
#  8476434: 'John Gibson',
#  8476438: 'Brandon Saad',
#  8476441: 'Joel Edmundson',
#  8476442: 'Matt Nieto',
#  8476448: 'William Karlsson',
#  8476453: 'Nikita Kucherov',
#  8476389: 'Vincent Trocheck',
#  8476391: 'T.J. Tynan',
#  8476392: 'Adam Lowry',
#  8476393: 'Nick Cousins',
#  8476399: 'Blake Coleman',
#  8476412: 'Jordan Binnington',
#  8476419: 'Jean-Gabriel Pageau',
#  8476422: 'Mike Reilly',
#  8476372: 'Nick Seeler',
#  8476374: 'Sean Kuraly',
#  8476312: 'Josh Manson',
#  8476316: 'Laurent Brossoit',
#  8476323: 'Max McCormick',
#  8476329: 'Travis Boyd',
#  8476331: 'Dylan DeMelo',
#  8476341: 'Anton Forsberg',
#  8476278: 'Colin Blackwell',
#  8476292: 'Ondrej Palat',
#  8473986: 'Alex Killorn',
#  8476792: 'Torey Krug',
#  8475191: 'Reilly Smith',
#  8475208: 'Brian Dumoulin',
#  8476853: 'Morgan Rielly',
#  8476854: 'Hampus Lindholm',
#  8476884: 'Derrick Pouliot',
#  8476885: 'Jacob Trouba',
#  8476887: 'Filip Forsberg',
#  8476889: 'Radek Faksa',
#  8476878: 'Zemgus Girgensons',
#  8476879: 'Cody Ceci',
#  8476880: 'Tom Wilson',
#  8476881: 'Tomas Hertl',
#  8476882: 'Teuvo Teravainen',
#  8476883: 'Andrei Vasilevskiy',
#  8476872: 'Scott Laughton',
#  8476873: 'Mark Jankowski',
#  8476874: 'Olli Maatta',
#  8476875: 'Mike Matheson',
#  8476867: 'Brendan Gaunce',
#  8476869: 'Brady Skjei',
#  8476871: 'Tanner Pearson',
#  8476539: 'Jonathan Marchessault',
#  8474602: 'Justin Schultz',
#  8476861: 'Oscar Dansk',
#  8476858: 'Phillip Di Giuseppe',
#  8476931: 'Jake McCabe',
#  8476932: 'Anthony Stolarz',
#  8476924: 'Martin Frk',
#  8476925: 'Colton Sissons',
#  8476927: 'Teddy Blueger',
#  8476921: 'Jordan Martinook',
#  8476923: 'Damon Severson',
#  8476913: 'Devin Shore',
#  8476914: 'Joonas Korpisalo',
#  8476917: 'Adam Pelech',
#  8476918: 'Jimmy Vesey',
#  8476902: 'Esa Lindell',
#  8476904: 'Chris Driedger',
#  8476905: 'Chandler Stephenson',
#  8476906: 'Shayne Gostisbehere',
#  8476897: 'Oskar Sundqvist',
#  8483575: 'Matt Murray',
#  8476899: 'Matt Murray',
#  8476891: 'Matt Grzelcyk',
#  8476892: 'Colton Parayko',
#  8476979: 'Erik Gustafsson',
#  8475640: 'Erik Gustafsson',
#  8476981: 'Josh Anderson',
#  8476967: 'Brett Kulak',
#  8476960: 'Andreas Athanasiou',
#  8476958: 'Jaccob Slavin',
#  8476945: 'Connor Hellebuyck',
#  8476941: 'Connor Carrick',
#  8477018: 'Ben Hutton',
#  8477021: 'Alexander Kerfoot',
#  8476525: 'Colin Miller',
#  8477015: 'Connor Brown',
#  8476999: 'Linus Ullmark',
#  8476994: 'Vinnie Hinostroza',
#  8476988: 'Matt Benning',
#  8477046: 'Joakim Ryan',
#  8477073: 'Kurtis MacDermid',
#  8475314: 'Anders Lee',
#  8477220: 'Nate Schmidt',
#  8477234: 'Troy Grosenick',
#  8475287: 'Erik Haula',
#  8477244: 'Chad Ruhwedel',
#  8475324: 'Nick Jensen',
#  8476822: 'Luke Glendening',
#  8477492: 'Nathan MacKinnon',
#  8477493: 'Aleksander Barkov',
#  8477494: 'Jonathan Drouin',
#  8477495: 'Seth Jones',
#  8477496: 'Elias Lindholm',
#  8477497: 'Sean Monahan',
#  8477498: 'Darnell Nurse',
#  8477499: 'Rasmus Ristolainen',
#  8477500: 'Bo Horvat',
#  8477501: 'Valeri Nichushkin',
#  8477503: 'Max Domi',
#  8477504: 'Josh Morrissey',
#  8477506: 'Ryan Pulock',
#  8477507: 'Nikita Zadorov',
#  8477508: 'Curtis Lazar',
#  8477511: 'Anthony Mantha',
#  8477444: 'Andre Burakovsky',
#  8477446: 'Michael McCarron',
#  8477447: 'Shea Theodore',
#  8477450: 'Jason Dickinson',
#  8477451: 'Ryan Hartman',
#  8477456: 'J.T. Compher',
#  8477462: 'Robert Hagg',
#  8477463: 'Steven Santini',
#  8477465: 'Tristan Jarry',
#  8477473: 'Justin Bailey',
#  8477476: 'Artturi Lehkonen',
#  8477478: 'William Carrier',
#  8477479: 'Tyler Bertuzzi',
#  8477480: 'Eric Comrie',
#  8477482: 'Zach Sanford',
#  8477484: 'Spencer Martin',
#  8477488: 'Brett Pesce',
#  8477401: 'John Hayden',
#  8477402: 'Pavel Buchnevich',
#  8477404: 'Jake Guentzel',
#  8477405: 'Marcus Hogberg',
#  8477406: 'Mattias Janmark',
#  8477407: 'Anthony Duclair',
#  8477409: 'Carter Verhaeghe',
#  8477416: 'Oliver Bjorkstrand',
#  8477424: 'Juuse Saros',
#  8477425: 'Miles Wood',
#  8477426: 'Nicholas Paul',
#  8477429: 'Andrew Copp',
#  8477433: 'Ben Harpur',
#  8477435: 'Ryan Graves',
#  8477392: 'Hudson Fasching',
#  8477353: 'Tyler Motte',
#  8477359: 'Tucker Poolman',
#  8477365: 'Connor Clifton',
#  8477369: 'Carson Soucy',
#  8477380: 'Jonny Brodzinski',
#  8477384: 'Josh Brown',
#  8477320: 'Anton Blidh',
#  8477330: 'Dominik Kubalik',
#  8477335: 'Kyle Burroughs',
#  8477346: 'MacKenzie Weegar',
#  8477573: 'Nathan Walker',
#  8477527: 'Ross Johnston',
#  8476624: 'Barclay Goodrow',
#  8476826: 'Yanni Gourde',
#  8477831: 'Pheonix Copley',
#  8477845: 'Trevor van Riemsdyk',
#  8477851: 'Jordan Oesterle',
#  8475343: 'Nic Dowd',
#  8477887: 'Patrick Brown',
#  8477931: 'Tomas Nosek',
#  8477932: 'Aaron Ekblad',
#  8477933: 'Sam Reinhart',
#  8477934: 'Leon Draisaitl',
#  8477935: 'Sam Bennett',
#  8477938: 'Haydn Fleury',
#  8477939: 'William Nylander',
#  8477940: 'Nikolaj Ehlers',
#  8477942: 'Kevin Fiala',
#  8477944: 'Jakub Vrana',
#  8477946: 'Dylan Larkin',
#  8477947: 'Sonny Milano',
#  8477948: 'Travis Sanheim',
#  8477949: 'Alex Tuch',
#  8477950: 'Tony DeAngelo',
#  8477951: 'Nick Schmaltz',
#  8477952: 'Robby Fabbri',
#  8477953: 'Kasperi Kapanen',
#  8477955: 'Jared McCann',
#  8477956: 'David Pastrnak',
#  8477960: 'Adrian Kempe',
#  8477962: 'Brendan Lemieux',
#  8477964: 'Ivan Barbashev',
#  8477967: 'Thatcher Demko',
#  8477968: 'Alex Nedeljkovic',
#  8477969: 'Marcus Pettersson',
#  8477970: 'Vitek Vanecek',
#  8477971: 'Andreas Englund',
#  8477979: 'Nicolas Aube-Kubel',
#  8477986: 'Brandon Montour',
#  8477987: 'Ryan Donato',
#  8477989: 'Christian Dvorak',
#  8477992: 'Jonas Johansson',
#  8477993: 'Justin Kirkland',
#  8477998: 'Warren Foegele',
#  8478007: 'Elvis Merzlikins',
#  8478009: 'Ilya Sorokin',
#  8478010: 'Brayden Point',
#  8478013: 'Jake Walman',
#  8478017: 'Mark Friedman',
#  8478020: 'Michael Amadio',
#  8478021: 'William Lagesson',
#  8478024: 'Ville Husso',
#  8478038: 'Devon Toews',
#  8478039: 'Kaapo Kahkonen',
#  8478042: 'Viktor Arvidsson',
#  8478043: 'Sam Lafferty',
#  8478046: 'Danton Heinen',
#  8478047: 'Michael Bunting',
#  8478048: 'Igor Shesterkin',
#  8478051: 'Max Willman',
#  8478055: 'Gustav Forsling',
#  8478057: 'Dakota Joshua',
#  8478062: 'Dysin Mayo',
#  8478104: 'Sammy Blais',
#  8478109: 'Victor Olofsson',
#  8478115: 'Pierre Engvall',
#  8478133: 'Jake Evans',
#  8478136: 'Jake Middleton',
#  8477839: 'Conor Sheary',
#  8477070: "Liam O'Brien",
#  8477903: 'Garnet Hathaway',
#  8478178: 'Darren Raddysh',
#  8477919: 'Frederick Gaudreau',
#  8478173: 'Hayden Hodgson',
#  8478176: 'Joe Hicketts',
#  8478366: 'Frank Vatrano',
#  8478542: 'Evan Rodrigues',
#  8478550: 'Artemi Panarin',
#  8478569: 'Noel Acciari',
#  8478585: 'Derek Ryan',
#  8478402: 'Connor McDavid',
#  8478403: 'Jack Eichel',
#  8478440: 'Dylan Strome',
#  8478483: 'Mitchell Marner',
#  8478396: 'Noah Hanifin',
#  8478401: 'Pavel Zacha',
#  8478500: 'Ivan Provorov',
#  8478460: 'Zach Werenski',
#  8478414: 'Timo Meier',
#  8478420: 'Mikko Rantanen',
#  8478474: 'Lawson Crouse',
#  8478498: 'Jake DeBrusk',
#  8478445: 'Mathew Barzal',
#  8478398: 'Kyle Connor',
#  8478469: 'Thomas Chabot',
#  8478493: 'Joel Eriksson Ek',
#  8478492: 'Ilya Samsonov',
#  8478444: 'Brock Boeser',
#  8478439: 'Travis Konecny',
#  8478458: 'Jack Roslovic',
#  8478454: 'Noah Juulsen',
#  8478463: 'Anthony Beauvillier',
#  8478432: 'Christian Fischer',
#  8478477: 'Mitchell Stephens',
#  8480222: 'Sebastian Aho',
#  8478427: 'Sebastian Aho',
#  8478443: 'Brandon Carlo',
#  8478421: 'A.J. Greer',
#  8478406: 'Mackenzie Blackwood',
#  8478416: 'Erik Cernak',
#  8478466: 'Daniel Sprong',
#  8478424: 'Jansen Harkins',
#  8478449: 'Roope Hintz',
#  8478413: 'Jordan Greenway',
#  8478468: 'Jeremy Lauzon',
#  8478397: 'Rasmus Andersson',
#  8478508: 'Yakov Trenin',
#  8478407: 'Vince Dunn',
#  8478399: 'Jonas Siegenthaler',
#  8478831: 'Kevin Stenlund',
#  8478430: 'Oliver Kylington',
#  8478476: 'Kyle Capobianco',
#  8478434: 'Keegan Kolesar',
#  8478433: 'Felix Sandstrom',
#  8478519: 'Anthony Cirelli',
#  8478435: 'Dan Vladar',
#  8478499: 'Adin Hill',
#  8478470: 'Sam Montembeault',
#  8478438: 'Tommy Novak',
#  8478502: 'Dennis Gilbert',
#  8478840: 'Will Borgen',
#  8478462: 'Nicolas Roy',
#  8478841: 'Colton White',
#  8478409: 'Anthony Richard',
#  8478846: 'Christian Wolanin',
#  8478450: 'Parker Wotherspoon',
#  8478851: 'Alexandre Carrier',
#  8478446: 'Glenn Gawdin',
#  8478452: 'Caleb Jones',
#  8478472: 'Mathieu Joseph',
#  8478854: 'Ryan Shea',
#  8478856: 'Conor Garland',
#  8478451: 'Ethan Bear',
#  8478859: 'Niko Mikkola',
#  8478864: 'Kirill Kaprizov',
#  8478872: 'Karel Vejmelka',
#  8478873: 'Troy Terry',
#  8478874: 'Adam Gaudette',
#  8478507: 'John Marino',
#  8478881: 'Brett Seney',
#  8478882: 'Vladislav Gavrikov',
#  8478888: 'Cameron Hughes',
#  8478233: 'Andrew Mangiapane',
#  8478891: 'Mason Appleton',
#  8478147: 'Bokondji Imama',
#  8478905: 'Ivan Fedotov',
#  8478911: 'Matt Roy',
#  8478916: 'Joey Daccord',
#  8477810: 'Joel Hanley',
#  8477541: 'Dakota Mermis',
#  8479026: 'Philippe Myers',
#  8478224: 'Luke Philp',
#  8478967: 'Lane Pederson',
#  8478970: 'Jalen Chatfield',
#  8478971: 'Connor Ingram',
#  8478956: 'Samuel Laberge',
#  8479066: 'Ryan Lomberg',
#  8478975: 'Mason Marchment',
#  8478211: 'Dryden Hunt',
#  8479293: 'Brandon Tanev',
#  8479292: 'Charlie Lindgren',
#  8479312: 'Alex Lyon',
#  8479442: 'Troy Stecher',
#  8479496: 'David Rittich',
#  8479318: 'Auston Matthews',
#  8479339: 'Patrik Laine',
#  8479400: 'Pierre-Luc Dubois',
#  8479344: 'Jesse Puljujarvi',
#  8479314: 'Matthew Tkachuk',
#  8479343: 'Clayton Keller',
#  8479410: 'Mikhail Sergachev',
#  8479370: 'Tyson Jost',
#  8479366: 'Logan Brown',
#  8479402: 'Jake Bean',
#  8479325: 'Charlie McAvoy',
#  8479316: 'Luke Kunin',
#  8479345: 'Jakob Chychrun',
#  8479371: 'Dante Fabbro',
#  8479378: 'Logan Stanley',
#  8479356: 'Kieffer Bellows',
#  8479395: 'Dennis Cholowski',
#  8479328: 'Julien Gauthier',
#  8479368: 'Max Jones',
#  8479362: 'Riley Tufte',
#  8479420: 'Tage Thompson',
#  8479353: 'Brett Howden',
#  8479365: 'Trent Frederic',
#  8479351: 'Sam Steel',
#  8479335: 'Rasmus Asplund',
#  8479369: 'Andrew Peeke',
#  8479385: 'Jordan Kyrou',
#  8479337: 'Alex DeBrincat',
#  8479414: 'Nathan Bastian',
#  8479383: 'Boris Katchouk',
#  8479379: 'Givani Smith',
#  8479398: 'Samuel Girard',
#  8479324: 'Ryan Lindgren',
#  8479348: 'Kale Clague',
#  8479425: 'Filip Hronek',
#  8479406: 'Filip Gustavsson',
#  8479336: 'Carl Grundstrom',
#  8479390: 'Taylor Raddysh',
#  8479580: 'Dylan Gambrell',
#  8479361: 'Joseph Woll',
#  8479367: 'William Lockwood',
#  8479323: 'Adam Fox',
#  8479341: 'Cam Dineen',
#  8479315: 'Joey Anderson',
#  8479372: 'Josh Mahura',
#  8479578: 'Casey Fitzgerald',
#  8479518: 'Fredrik Karlstrom',
#  8479419: 'Brett Murray',
#  8479387: 'Keaton Middleton',
#  8479520: 'Brandon Duhaime',
#  8479523: 'Lucas Carlsson',
#  8479393: 'Noah Gregor',
#  8479421: 'Jacob Moverare',
#  8479388: 'Riley Stillman',
#  8479525: 'Ross Colton',
#  8479320: 'Max Lajoie',
#  8479591: 'Michael Eyssimont',
#  8479359: 'Beck Malenstyn',
#  8479536: 'Axel Jonsson-Fjallby',
#  8479542: 'Brandon Hagel',
#  8479543: 'Michael Pezzetta',
#  8479407: 'Jesper Bratt',
#  8479547: 'Matthew Phillips',
#  8479550: 'Tanner Laczynski',
#  8479576: 'Vincent Desharnais',
#  8479602: 'Jeremy Davies',
#  8479619: 'Michael Carcone',
#  8479675: 'Trevor Moore',
#  8479671: 'Mathieu Olivier',
#  8479313: 'Zach Sawchenko',
#  8479661: 'Tanner Jeannot',
#  8479705: 'Jeffrey Viel',
#  8479772: 'Zack MacEwen',
#  8479638: 'Justin Brazeau',
#  8479639: 'Dylan Coghlan',
#  8479193: 'Casey DeSmith',
#  8479291: 'Kevin Rooney',
#  8479416: 'Ben Gleason',
#  8478146: 'Matthew Highmore',
#  8479944: 'Zach Aston-Reese',
#  8479968: 'Vinni Lettieri',
#  8480084: 'Nick DeSimone',
#  8480113: 'Alex Iafallo',
#  8480145: 'Neal Pionk',
#  8480144: 'David Kampf',
#  8480157: 'Calle Rosen',
#  8480172: 'Jan Rutta',
#  8480002: 'Nico Hischier',
#  8480036: 'Miro Heiskanen',
#  8480069: 'Cale Makar',
#  8480012: 'Elias Pettersson',
#  8479996: 'Cody Glass',
#  8479999: 'Casey Mittelstadt',
#  8479992: 'Michael Rasmussen',
#  8480015: 'Owen Tippett',
#  8480014: 'Gabriel Vilardi',
#  8480039: 'Martin Necas',
#  8480018: 'Nick Suzuki',
#  8480073: 'Erik Brannstrom',
#  8479976: 'Juuso Valimaki',
#  8480043: 'Timothy Liljegren',
#  8480001: 'Urho Vaakanainen',
#  8480064: 'Josh Norris',
#  8480023: 'Robert Thomas',
#  8480078: 'Filip Chytil',
#  8479977: 'Kailer Yamamoto',
#  8480058: 'Pierre-Olivier Joseph',
#  8480068: 'Ryan Poehling',
#  8479979: 'Jake Oettinger',
#  8480028: 'Morgan Frost',
#  8480032: 'Shane Bowers',
#  8480035: 'Henri Jokiharju',
#  8480009: 'Eeli Tolvanen',
#  8480011: 'Klim Kostin',
#  8479982: 'Conor Timmins',
#  8479986: 'Kole Lind',
#  8479980: 'Nicolas Hague',
#  8480003: 'Jesper Boqvist',
#  8480184: 'Gustav Lindstrom',
#  8480027: 'Jason Robertson',
#  8479994: 'Jaret Anderson-Dolan',
#  8480185: 'Eetu Luostarinen',
#  8480049: 'Dylan Samberg',
#  8480074: 'Alexandre Texier',
#  8480071: 'Robin Salo',
#  8479983: 'Mario Ferraro',
#  8480021: 'Jack Studnicka',
#  8480045: 'Ukko-Pekka Luukkonen',
#  8479981: 'Jonah Gadjovich',
#  8479991: 'Jake Leschyshyn',
#  8480188: 'Fabian Zetterlund',
#  8480022: 'Michael DiPietro',
#  8480007: 'Jonas Rondbjerg',
#  8479987: 'Morgan Geekie',
#  8480025: 'MacKenzie Entwistle',
#  8480191: 'Matt Villalta',
#  8480192: 'Johnathan Kovacevic',
#  8479973: 'Stuart Skinner',
#  8480054: 'Reilly Walsh',
#  8480075: 'Cameron Crotty',
#  8480193: 'Daniil Tarasov',
#  8476549: 'Daniil Tarasov',
#  8480056: 'Jack Rathbone',
#  8479972: 'Mason Shaw',
#  8480196: 'Jacob Bryson',
#  8479998: 'Mikey Anderson',
#  8480199: 'Eetu Makiniemi',
#  8480280: 'Jeremy Swayman',
#  8480281: 'Alexey Toropchenko',
#  8480205: 'Emil Bemstrom',
#  8480208: 'Drake Batherson',
#  8480220: 'Noah Cates',
#  8480238: 'Jiri Patera',
#  8480246: 'Nick Perbix',
#  8480289: 'Morgan Barron',
#  8480292: 'Carson Meyer',
#  8480259: 'Ben Jones',
#  8480051: 'Cayden Primeau',
#  8480267: 'Sammy Walker',
#  8480274: 'Philip Kemp',
#  8480382: 'Alexandar Georgiev',
#  8480420: 'Collin Delia',
#  8479718: 'Alex Barre-Boulet',
#  8480336: 'Sean Walker',
#  8479439: 'Jacob MacDonald',
#  8475968: 'Alex Belzile',
#  8480448: 'Parker Kelly',
#  8480459: 'Pius Suter',
#  8480355: 'Mark Kastelic',
#  8480727: 'Zach Whitecloud',
#  8480748: 'Kiefer Sherwood',
#  8480762: 'Eric Robinson',
#  8480925: 'Pavel Francouz',
#  8480950: 'Ilya Lyubushkin',
#  8480839: 'Rasmus Dahlin',
#  8480830: 'Andrei Svechnikov',
#  8480829: 'Jesperi Kotkaniemi',
#  8480801: 'Brady Tkachuk',
#  8480849: 'Barrett Hayton',
#  8480821: 'Filip Zadina',
#  8480800: 'Quinn Hughes',
#  8480871: 'Adam Boqvist',
#  8480803: 'Evan Bouchard',
#  8480789: 'Oliver Wahlstrom',
#  8480865: 'Noah Dobson',
#  8480848: 'Ty Dellandrea',
#  8480797: 'Joel Farabee',
#  8480844: 'Grigori Denisenko',
#  8480883: 'Ty Smith',
#  8480853: 'Liam Foudy',
#  8480845: 'Rasmus Kupari',
#  8480817: "K'Andre Miller",
#  8480806: 'Isac Lundestrom',
#  8480879: 'Jacob Bernard-Docker',
#  8480878: 'Nils Lundkvist',
#  8480873: 'Rasmus Sandin',
#  8480813: 'Joe Veleno',
#  8480823: 'Alexander Alexeyev',
#  8480807: 'Mattias Samuelsson',
#  8481013: 'Jonatan Berggren',
#  8481058: 'Jesse Ylonen',
#  8481014: 'Alexander Romanov',
#  8480802: 'Ryan McLeod',
#  8480835: 'Jack Drury',
#  8481059: 'Scott Perunovich',
#  8480796: 'Martin Fehervary',
#  8480893: 'Kirill Marchenko',
#  8480874: 'Adam Ginning',
#  8480851: 'Akil Thomas',
#  8480434: 'Sean Durzi',
#  8480870: 'Bo Groulx',
#  8480860: 'Kevin Bahl',
#  8481019: 'David Gustafsson',
#  8480855: 'Jack McBain',
#  8481020: 'Justus Annunen',
#  8480890: 'Jan Jenik',
#  8480831: 'Alec Regula',
#  8480887: 'Jordan Harris',
#  8480834: 'Ty Emberson',
#  8480880: 'Jakub Lauko',
#  8480843: 'Lukas Dostal',
#  8481024: 'Linus Karlsson',
#  8480979: 'Nathan Smith',
#  8468503: 'Nathan Smith',
#  8480980: 'Connor Dewar',
#  8480836: 'Jonathan Gruden',
#  8481028: 'Martin Pospisil',
#  8480981: 'Joel Hofer',
#  8481030: 'Jack St. Ivany',
#  8481031: 'Ivan Prosvetov',
#  8481032: 'Paul Cotter',
#  8480439: 'Mac Hollowell',
#  8480798: 'Philipp Kurashev',
#  8481056: 'Spencer Stastney',
#  8481033: 'Akira Schmid',
#  8481070: 'Hugh McGing',
#  8481035: 'Samuel Ersson',
#  8480820: 'Filip Kral',
#  8480990: 'Declan Chisholm',
#  8480992: 'Magnus Chrona',
#  8480995: 'Pontus Holmberg',
#  8480867: 'Kevin Mandolese',
#  8480891: 'Michael Kesselring',
#  8481068: 'Yegor Sharangovich',
#  8481043: 'Cole Koepke',
#  8481004: 'Josiah Slavin',
#  8481006: 'Tyler Tucker',
#  8481186: "Logan O'Connor",
#  8481178: 'Egor Zamula',
#  8481093: 'Rafael Harvey-Pinard',
#  8480313: 'Logan Thompson',
#  8481122: 'Simon Benoit',
#  8481161: 'Jake Christiansen',
#  8481167: 'Brayden Pachal',
#  8481237: 'Kyle MacLean',
#  8481147: 'Reese Johnson',
#  8481422: 'Jacob Lucchini',
#  8481441: 'Joe Snively',
#  8481477: 'Nico Sturm',
#  8481481: 'Blake Lizotte',
#  8481624: 'Ilya Mikheyev',
#  8481641: 'Joel Kiviranta',
#  8481559: 'Jack Hughes',
#  8481554: 'Kaapo Kakko',
#  8481523: 'Kirby Dach',
#  8481524: 'Bowen Byram',
#  8481532: 'Alex Turcotte',
#  8481542: 'Moritz Seider',
#  8481528: 'Dylan Cozens',
#  8481598: 'Philip Broberg',
#  8481533: 'Trevor Zegras',
#  8481617: 'Vasily Podkolzin',
#  8481557: 'Matt Boldy',
#  8481519: 'Spencer Knight',
#  8481546: 'Cam York',
#  8481540: 'Cole Caufield',
#  8481618: 'Alex Newhook',
#  8481522: 'Peyton Krebs',
#  8481581: 'Thomas Harley',
#  8481572: 'Ville Heinola',
#  8481591: 'Sam Poulin',
#  8481600: 'Tobias Bjornfot',
#  8481601: 'Simon Holmstrom',
#  8481577: 'Philip Tomasino',
#  8481580: 'Connor McMichael',
#  8481592: 'Jakob Pelletier',
#  8481518: 'Nolan Foote',
#  8481556: 'John Beecher',
#  8481596: 'Shane Pinto',
#  8481560: 'Arthur Kaliyev',
#  8481553: 'Bobby Brink',
#  8481611: 'Pyotr Kochetkov',
#  8481544: 'Mads Sogaard',
#  8481534: 'Raphael Lavoie',
#  8481535: 'Nils Hoglander',
#  8481527: 'Kaedan Korczak',
#  8481568: 'Alex Vlasic',
#  8481585: 'Egor Afanasyev',
#  8481239: 'Samuel Fagemo',
#  8481582: 'Nicholas Robertson',
#  8481517: 'Brett Leason',
#  8481541: 'Samuel Bolduc',
#  8481537: 'Nikita Okhotiuk',
#  8481543: 'Nikita Alexandrov',
#  8481708: 'Zac Jones',
#  8481206: 'John Ludvig',
#  8481550: 'Adam Beckman',
#  8481604: 'Pavel Dorofeyev',
#  8481578: 'Graeme Clarke',
#  8481655: 'Cole Schwindt',
#  8481656: 'Aliaksei Protas',
#  8481606: 'Jordan Spence',
#  8481740: 'Tyce Thompson',
#  8481711: 'Matias Maccelli',
#  8481712: 'Matej Blumel',
#  8481716: 'Dmitri Voronkov',
#  8481720: 'Nick Abruzzese',
#  8481668: 'Arturs Silovs',
#  8481726: 'Adam Edstrom',
#  8481701: 'Santeri Hatakka',
#  8481703: 'Valtteri Puustinen',
#  8481704: 'Juuso Parssinen',
#  8481692: 'Dustin Wolf',
#  8481812: 'Nikolai Knyzhov',
#  8481827: 'Ben McCartney',
#  8481461: 'Corey Schueneman',
#  8481462: 'Mason Morelli',
#  8482055: "Drew O'Connor",
#  8482061: 'Brandon Biro',
#  8482062: 'Cole Smith',
#  8482067: 'Connor Mackey',
#  8482070: 'Mitchell Chaffee',
#  8482072: 'Jack Ahcan',
#  8482245: 'Artem Zub',
#  8482109: 'Alexis Lafreniere',
#  8482124: 'Quinton Byfield',
#  8482116: 'Tim Stutzle',
#  8482078: 'Lucas Raymond',
#  8482105: 'Jake Sanderson',
#  8482142: 'Jamie Drysdale',
#  8482125: 'Alexander Holtz',
#  8482097: 'Jack Quinn',
#  8482079: 'Marco Rossi',
#  8482149: 'Cole Perfetti',
#  8482137: 'Yaroslav Askarov',
#  8482113: 'Anton Lundell',
#  8482093: 'Seth Jarvis',
#  8482077: 'Dylan Holloway',
#  8482087: 'Kaiden Guhle',
#  8482117: 'Lukas Reichel',
#  8482110: 'Dawson Mercer',
#  8482073: 'Braden Schneider',
#  8482475: 'Yegor Chinakhov',
#  8482159: 'Tyson Foerster',
#  8482074: 'Connor Zary',
#  8482111: 'Justin Barron',
#  8482089: 'Jake Neighbours',
#  8482092: 'Ridly Greig',
#  8482153: 'Brendan Brisson',
#  8482145: 'Mavrik Bourque',
#  8482162: 'Roby Jarventie',
#  8482175: 'JJ Peterka',
#  8482133: 'Thomas Bordeleau',
#  8482146: 'Luke Evangelista',
#  8482157: 'Will Cuylle',
#  8482201: 'Gage Goncalves',
#  8482447: 'Leevi Merilainen',
#  8482147: 'Jean-Luc Foudy',
#  8482076: 'Nico Daws',
#  8482088: 'Justin Sourdif',
#  8482445: 'Devin Cooley',
#  8482460: 'Matt Rempe',
#  8482496: 'Nils Aman',
#  8481133: 'Cole Reinhardt',
#  8482197: 'Adam Raska',
#  8482470: 'Ilya Solovyov',
#  8482623: 'Josh Dunne',
#  8482624: 'Daniil Miromanov',
#  8482635: 'Mike Hardman',
#  8482634: 'Alex Steeves',
#  8482641: 'Matt Kiersted',
#  8482652: 'Walker Duehr',
#  8479941: 'Justin Danforth',
#  8482821: 'Arvid Soderblom',
#  8482408: 'Jeff Malott',
#  8482671: 'Owen Power',
#  8482665: 'Matty Beniers',
#  8482745: 'Mason McTavish',
#  8482660: 'Kent Johnson',
#  8482762: 'Simon Edvinsson',
#  8482667: 'William Eklund',
#  8482730: 'Brandt Clarke',
#  8482699: 'Dylan Guenther',
#  8482705: 'Cole Sillinger',
#  8482747: 'Brennan Othmann',
#  8482661: 'Jesper Wallstedt',
#  8482740: 'Wyatt Johnston',
#  8482803: 'Olen Zellweger',
#  8482858: 'Ryker Evans',
#  8482702: 'Logan Stankoven',
#  8482691: 'Aatu Raty',
#  8482655: 'J.J. Moser',
#  8482749: 'Joshua Roy',
#  8482399: 'Billy Sweezey',
#  8482964: 'Arber Xhekaj',
#  8482824: 'Nick Cicek',
#  8481789: 'Tye Kartye',
#  8483397: 'Marc McLaughlin',
#  8483398: 'Declan Carlile',
#  8483407: 'Brandon Scanlin',
#  8483395: 'Arshdeep Bains',
#  8483531: 'Brian Halonen',
#  8483565: 'Nick Blankenburg',
#  8483567: 'Georgii Merkulov',
#  8483570: 'Ben Meyers',
#  8482259: 'Bobby McMann',
#  8483609: 'Adam Klapka',
#  8483630: 'Pavol Regenda',
#  8483808: 'Andrei Kuzmenko',
#  8483515: 'Juraj Slafkovsky',
#  8483495: 'Simon Nemec',
#  8483524: 'Shane Wright',
#  8483460: 'David Jiricek',
#  8483466: 'Kevin Korchinski',
#  8483464: 'Marco Kasper',
#  8483512: 'Matt Savoie',
#  8483490: 'Pavel Mintyukov',
#  8483499: 'Liam Ohgren',
#  8483468: 'Jiri Kulich',
#  8483471: 'Brad Lambert',
#  8483482: 'Tristan Luneau',
#  8483505: 'Matthew Poitras',
#  8483546: 'Marshall Rifai',
#  8481754: 'Nikita Nesterenko',
#  8483493: 'Frank Nazar',
#  8482122: 'Brock Faber',
#  8482176: 'Wyatt Kaiser',
#  8481683: 'Aidan McDonough',
#  8482659: 'Josh Doan',
#  8482221: 'Devon Levi',
#  8484125: 'Hunter McKown',
#  8482095: 'Tyler Kleven',
#  8481567: 'Henry Thrun',
#  8482081: 'Sean Farrell',
#  8482155: 'Alex Laferriere',
#  8482679: 'Matt Coronato',
#  8482666: 'Scott Morrow',
#  8484254: 'Akito Hirose',
#  8484256: 'Jake Livingstone',
#  8481605: 'Jackson LaCombe',
#  8482809: 'Jackson Blake',
#  8482511: 'Mason Lohrei',
#  8484287: 'Cole McWard',
#  8482684: 'Luke Hughes',
#  8482720: 'Matthew Knies',
#  8484304: 'Uvis Balinskis',
#  8479522: 'Hardy Haman Aktell',
#  8482713: 'Mackie Samoskevich',
#  8484321: 'Nikolas Matinpalo',
#  8484144: 'Connor Bedard',
#  8484153: 'Leo Carlsson',
#  8484166: 'Adam Fantilli',
#  8484145: 'Zach Benson',
#  8484203: 'Bradly Nadeau',
#  8484149: 'Gavin Brindley',
#  8481042: 'Nikolai Kovalenko',
#  8483431: 'Logan Cooley',
#  8482172: 'Landon Slaggert',
#  8482177: 'Marat Khusnutdinov',
#  8482118: 'Sam Colangelo',
#  8483491: 'Ivan Miroshnichenko',
#  8484258: 'Sam Malinski',
#  8484326: 'Patrik Koch',
#  8483457: 'Lane Hutson',
#  8483445: 'Cutter Gauthier',
#  8484911: 'Collin Graf'}
